# %%
from transformers import MambaConfig, MambaForCausalLM, AutoTokenizer

# %%
model130 = MambaForCausalLM.from_pretrained("state-spaces/mamba-130m-hf")
# Out:
# config.json:   0%|          | 0.00/895 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/517M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 MambaForCausalLM.from_pretrained("state-spaces/mamba-130m-hf")
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/transformers/modeling_utils.py:3190, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3174 try:
#    3175     # Load from URL or cache if already cached
#    3176     cached_file_kwargs = {
#    3177         "cache_dir": cache_dir,
#    3178         "force_download": force_download,
#    (...)
#    3188         "_commit_hash": commit_hash,
#    3189     }
# ...
